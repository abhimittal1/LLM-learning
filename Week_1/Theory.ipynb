# %% [markdown]
# Types of LLM :-
#
# | Category     | Types                                    |
# | ------------ | ---------------------------------------- |
# | Training     | Autoregressive, Autoencoding, Seq-to-Seq |
# | Architecture | Transformer-based                        |
# | Access       | Open-source, Closed-source               |
# | Capability   | Text-only, Multimodal                    |
# | Tuning       | Base, Instruction-tuned, Domain-specific |

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# %%
from openai import OpenAI
client = OpenAI(api_key=api_key)
response = client.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Explain the theory of relativity in simple terms."}
    ]
)
print(response.choices[0].message.content)
# Out:
# Here’s a simple way to think about the theory of relativity, which has two big parts: Special Relativity (SR) and General Relativity (GR).
#
# What relativity is about
# - It says the laws of physics are the same for everyone in uniform motion.
# - It also says the speed of light in empty space is the same for all observers, no matter how they’re moving.
# - Together, SR and GR tell us that measurements of time, space, and gravity depend on how you’re moving and how strong gravity is where you are.
#
# Special Relativity (SR) — movement and speed
# - No absolute rest: There isn’t a universal “true” time or space. Everything is measured relative to your motion.
# - Speed of light is constant: Light always travels at about 300,000 km/s, no matter how fast you’re moving.
# - Time can stretch (time dilation): A clock moving very fast ticks more slowly from the viewpoint of someone at rest.
# - Length can shrink (length contraction): An object moving very fast appears shorter in the direction it’s moving, to a stationary observer.
# - Simultaneity is relative: Whether two events happen at the same time can depend on who’s watching.
# - Energy and mass are linked: E = mc^2. As you speed up, you need more energy to keep accelerating, and energy contributes to the “effective” mass as you approach very high speeds.
#
# General Relativity (GR) — gravity as curved spacetime
# - Gravity isn’t just a force: Mass and energy bend the fabric of spacetime, and objects move along those bends.
# - Time runs differently near massive objects: Closer to a big mass, clocks run a bit slower (gravitational time dilation).
# - Light bends with gravity: Light travels along curved paths near massive objects (gravitational lensing).
# - Big predictions and effects: Black holes, gravitational waves, and the overall shape and expansion of the universe are described by GR.
# - Everyday consequence: GPS satellites have to account for both SR and GR effects to give accurate positions.
#
# Simple ways to picture it
# - Spacetime as a trampoline: Put a heavy ball on a stretched sheet to make a dip. If you roll a smaller ball nearby, it follows curved paths around the dip—that’s like how gravity bends motion.
# - The aging clock: If one twin travels very fast in a spaceship and comes back, they would be younger than the twin who stayed on Earth (a famous thought experiment called the twin paradox).
# - Time and gravity: Clocks nearer huge planets or stars tick slower than clocks far away.
#
# Common questions
# - Can we reach the speed of light? No for objects with mass; it would take infinite energy. Light isn’t a massive object, so it travels at c.
# - Is relativity “just a theory”? It’s a well-tested framework supported by countless experiments and observations across physics, from particle accelerators to GPS and astronomical observations.
# - Do SR and GR contradict each other? Not at all. SR works well in flat (or nearly flat) spacetime without strong gravity. GR reduces to SR in small, gravity-free regions.
#
# In short
# - Special Relativity: physics same for all moving observers; nothing can beat the speed of light; time, space, and mass-energy are interconnected.
# - General Relativity: gravity is the warping of spacetime by mass and energy; time and light are affected by gravity; the universe’s large-scale behavior follows from these ideas.
#
# If you’d like, I can tailor this to a specific audience (kids, students, or adults) or give a short, kid-friendly analogy or a couple of quick real-world examples.
